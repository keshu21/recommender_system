# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('C:\\Users\keshav\\Desktop\\kaggle\\PatientFood_choice.csv')

# %%
df.head()
df=df.drop(columns=['No_Pation'])

# %%
x=df.iloc[:,0:13]
x
y_new=[]
y=df["CLASS"]

a=0
for i in y:
    if(i=='N' or i=='N '):
        y_new.append(0)
    else:
        if(i=='Y' or i=='Y '):
            y_new.append(1)
        else:
            y_new.append(2)

y=y_new
x=x.drop(columns=['ID','Food_Choices'])
x
# Out:
#     Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI
# 0        F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 1        M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0
# 2        F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 3        F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0
# 4        M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0
# ..     ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...
# 795      M   68   3.9  51   10.7   3.6  1.2  1.4  1.7   0.5  36.0
# 796      M   61   7.2  78    9.1   6.5  1.5  1.4  0.9   0.5  33.0
# 797      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2
# 798      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4
# 799      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0
#
# [800 rows x 11 columns]

# %%
ind=0
for i in x['Gender']:
    if(i=='F'):
       x['Gender'][ind]=0
    else:
        x['Gender'][ind]=1
    ind=ind+1
# Out:
# C:\Users\keshav\AppData\Local\Temp\ipykernel_26660\1074600949.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Gender'][ind]=0
# C:\Users\keshav\AppData\Local\Temp\ipykernel_26660\1074600949.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Gender'][ind]=1

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming X_train, X_test, y_train, and y_test are already defined from the previous code

# Create and train the Logistic Regression model
model = LogisticRegression(random_state=42)
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print("Accuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 0.925
#
# Confusion Matrix:
#  [[ 22   0   2]
#  [  4 123   2]
#  [  1   3   3]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.81      0.92      0.86        24
#            1       0.98      0.95      0.96       129
#            2       0.43      0.43      0.43         7
#
#     accuracy                           0.93       160
#    macro avg       0.74      0.77      0.75       160
# weighted avg       0.93      0.93      0.93       160

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming X_train, X_test, y_train, and y_test are already defined from the previous code

# Create and train the Support Vector Machine (SVM) model
model = SVC(probability=True, random_state=42)
model.fit(X_train, y_train)

# Get predicted probabilities for each class on the test set
y_probabilities = model.predict_proba(X_test)

# The second column (index 1) represents the probability of class 1 (having diabetes)
probabilities_diabetes = y_probabilities[:, 1]

# Make predictions based on a probability threshold (e.g., 0.5)
threshold = 0.5
y_pred1 = (probabilities_diabetes > threshold).astype(int)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred1)
conf_matrix = confusion_matrix(y_test, y_pred1)
classification_rep = classification_report(y_test, y_pred1)

print("Accuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 0.925
#
# Confusion Matrix:
#  [[ 22   2   0]
#  [  3 126   0]
#  [  7   0   0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.92      0.79        24
#            1       0.98      0.98      0.98       129
#            2       0.00      0.00      0.00         7
#
#     accuracy                           0.93       160
#    macro avg       0.56      0.63      0.59       160
# weighted avg       0.90      0.93      0.91       160
# c:\Users\keshav\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming X_train, X_test, y_train, and y_test are already defined from the previous code

# Create and train the Random Forest model
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)

# Get predicted probabilities for each class on the test set
y_probabilities = model.predict_proba(X_test)

# The second column (index 1) represents the probability of class 1 (having diabetes)
probabilities_diabetes = y_probabilities[:, 1]

# Make predictions based on a probability threshold (e.g., 0.5)
threshold = 0.5
y_pred2 = (probabilities_diabetes > threshold).astype(int)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred2)
conf_matrix = confusion_matrix(y_test, y_pred2)
classification_rep = classification_report(y_test, y_pred2)

print("Accuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 0.95
#
# Confusion Matrix:
#  [[ 24   0   0]
#  [  1 128   0]
#  [  7   0   0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        24
#            1       1.00      0.99      1.00       129
#            2       0.00      0.00      0.00         7
#
#     accuracy                           0.95       160
#    macro avg       0.58      0.66      0.62       160
# weighted avg       0.92      0.95      0.93       160
# c:\Users\keshav\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming X_train, X_test, y_train, and y_test are already defined from the previous code

# Create and train the k-Nearest Neighbors (KNN) model
model = KNeighborsClassifier()
model.fit(X_train, y_train)

# Get predicted probabilities for each class on the test set
# KNN does not have a direct probability estimation, so we'll use a workaround
y_probabilities = model.predict_proba(X_test)  # This will return a uniform probability distribution

# For simplicity, we'll use the probability of the positive class (class 1) as an approximation
probabilities_diabetes = y_probabilities[:, 1]

# Make predictions based on a probability threshold (e.g., 0.5)
threshold = 0.5
y_pred3 = (probabilities_diabetes > threshold).astype(int)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred3)
conf_matrix = confusion_matrix(y_test, y_pred3)
classification_rep = classification_report(y_test, y_pred3)

print("Accuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 0.925
#
# Confusion Matrix:
#  [[ 22   2   0]
#  [  3 126   0]
#  [  6   1   0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.92      0.80        24
#            1       0.98      0.98      0.98       129
#            2       0.00      0.00      0.00         7
#
#     accuracy                           0.93       160
#    macro avg       0.56      0.63      0.59       160
# weighted avg       0.89      0.93      0.91       160
# c:\Users\keshav\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming X_train, X_test, y_train, and y_test are already defined from the previous code

# Create and train the Gradient Boosting model
model = GradientBoostingClassifier(random_state=42)
model.fit(X_train, y_train)

# Get predicted probabilities for each class on the test set
y_probabilities = model.predict_proba(X_test)

# The second column (index 1) represents the probability of class 1 (having diabetes)
probabilities_diabetes = y_probabilities[:, 1]

# Make predictions based on a probability threshold (e.g., 0.5)
threshold = 0.5
y_pred4 = (probabilities_diabetes > threshold).astype(int)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred4)
conf_matrix = confusion_matrix(y_test, y_pred4)
classification_rep = classification_report(y_test, y_pred4)

print("Accuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 0.95
#
# Confusion Matrix:
#  [[ 24   0   0]
#  [  1 128   0]
#  [  7   0   0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86        24
#            1       1.00      0.99      1.00       129
#            2       0.00      0.00      0.00         7
#
#     accuracy                           0.95       160
#    macro avg       0.58      0.66      0.62       160
# weighted avg       0.92      0.95      0.93       160
# c:\Users\keshav\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming X_train, X_test, y_train, and y_test are already defined from the previous code

# Create and train the Decision Tree model
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)

# Get predicted probabilities for each class on the test set
# Decision Trees don't directly provide probabilities, so we'll use a workaround
y_probabilities = model.predict_proba(X_test)  # This will return a uniform probability distribution

# For simplicity, we'll use the probability of the positive class (class 1) as an approximation
probabilities_diabetes = y_probabilities[:, 1]

# Make predictions based on a probability threshold (e.g., 0.5)
threshold = 0.5
y_pred5 = (probabilities_diabetes > threshold).astype(int)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred5)
conf_matrix = confusion_matrix(y_test, y_pred5)
classification_rep = classification_report(y_test, y_pred5)

print("Accuracy:", accuracy)
print("\nConfusion Matrix:\n", conf_matrix)
print("\nClassification Report:\n", classification_rep)
# Out:
# Accuracy: 0.9375
#
# Confusion Matrix:
#  [[ 22   2   0]
#  [  1 128   0]
#  [  7   0   0]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.73      0.92      0.81        24
#            1       0.98      0.99      0.99       129
#            2       0.00      0.00      0.00         7
#
#     accuracy                           0.94       160
#    macro avg       0.57      0.64      0.60       160
# weighted avg       0.90      0.94      0.92       160
# c:\Users\keshav\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...
